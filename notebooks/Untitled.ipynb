# %%
import pickle

with open("../data/processed/ibkr_2022_2025.pkl", "rb") as f:
    ib = pickle.load(f)

df = ib["2022"]["Trades.Stocks"]

# %%
df
# Out:
#        Header DataDiscriminator Asset Category Currency Symbol  \
# 0        Data             Order         Stocks      EUR   3BUS
# 1        Data             Order         Stocks      EUR   3BUS
# 2    SubTotal                           Stocks      EUR   3BUS
# 3        Data             Order         Stocks      EUR   3DES
# 4        Data             Order         Stocks      EUR   3DES
# ..        ...               ...            ...      ...    ...
# 181      Data             Order         Stocks      USD   VRNS
# 182      Data             Order         Stocks      USD   VRNS
# 183  SubTotal                           Stocks      USD   VRNS
# 184     Total                           Stocks      USD
# 185     Total                           Stocks      EUR
#
#                 Date/Time Quantity T. Price C. Price        Proceeds  \
# 0    2022-09-28, 04:46:51       30    62.96     60.6         -1888.8
# 1    2022-09-30, 09:46:08      -30       59    59.74            1770
# ...
