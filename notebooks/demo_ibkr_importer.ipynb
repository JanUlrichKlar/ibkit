# %%
# 📓 IBKR CSV Importer — Demo Notebook

import sys
import os
from pathlib import Path

# Ensure ibkit module is importable
sys.path.append(str(Path("..").resolve()))

from ibkit.importer.csv_importer import CSVImporter
import pickle
import pandas as pd

# 📁 Define paths
raw_data_dir = Path("data/raw")
processed_dir = Path("data/processed")

# 📦 Initialize importer
importer = CSVImporter(data_dir=raw_data_dir)

# 📄 List available files
files = importer.list_csv_files()
print("📄 CSV files found:", files)
# Out:
# 📄 CSV files found: ['U7212345_2021_2021.csv', 'U7212345_2022_2022.csv', 'U7212345_2023_2023.csv', 'U7212345_2024_2024.csv', 'U7212345_2025_2025.csv']

# %%
# 🛠️ Process and save all raw files
importer.process_all()
# Out:
# 📂 Processing U7212345_2021_2021.csv → saving to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2021
# 📦 Section processed: Statement_General → (5, 3)
# 📦 Section processed: Disclaimer_General → (1, 3)
# 📦 Section processed: Account Information_General → (7, 3)
# 📦 Section processed: Net Asset Value_General → (7, 7)
# 📦 Section processed: Net Asset Value_wRR → (1, 2)
# 📦 Section processed: Change in Combined NAV_General → (14, 3)
# 📦 Section processed: Mark-to-Market Performance Summary_General → (108, 13)
# 📦 Section processed: Realized & Unrealized Performance Summary_General → (102, 16)
# 📦 Section processed: Month & Year to Date Performance Summary_General → (89, 10)
# 📦 Section processed: Cash Report_General → (132, 9)
# 📦 Section processed: Open Positions_Stocks → (42, 13)
# 📦 Section processed: Collateral for Customer Borrowing_General → (16, 15)
# 📦 Section processed: Forex Balances_General → (3, 11)
# 📦 Section processed: Net Stock Position Summary_General → (38, 9)
# 📦 Section processed: Trades_Stocks → (210, 16)
# 📦 Section processed: Trades_Structured Products → (18, 16)
# 📦 Section processed: Trades_Forex → (93, 13)
# 📦 Section processed: Transaction Fees_General → (10, 11)
# 📦 Section processed: Corporate Actions_General → (5, 12)
# 📦 Section processed: Transfers_Stocks → (74, 16)
# 📦 Section processed: Transfers_Structured Products → (5, 16)
# 📦 Section processed: Deposits & Withdrawals_General → (72, 6)
# 📦 Section processed: Fees_General → (7, 7)
# 📦 Section processed: Dividends_General → (153, 6)
# 📦 Section processed: Withholding Tax_General → (110, 7)
# 📦 Section processed: Interest_General → (56, 6)
# 📦 Section processed: Interest Accruals_General → (19, 4)
# 📦 Section processed: Change in Dividend Accruals_General → (269, 15)
# 📦 Section processed: Borrow Fee Details_General → (256, 11)
# 📦 Section processed: Financial Instrument Information_Stocks → (82, 11)
# 📦 Section processed: Financial Instrument Information_Structured Products → (5, 11)
# ✓ Converted Month to Date to datetime in table shape (132, 9)
# ✓ Converted Year to Date to datetime in table shape (132, 9)
# ✓ Converted Date/Time to datetime in table shape (210, 16)
# ✓ Converted Date/Time to datetime in table shape (18, 16)
# ✓ Converted Date/Time to datetime in table shape (93, 11)
# ✓ Converted Date/Time to datetime in table shape (10, 11)
# ✓ Converted Report Date to datetime in table shape (5, 11)
# ✓ Converted Date/Time to datetime in table shape (5, 11)
# ✓ Converted Date to datetime in table shape (74, 15)
# ✓ Converted Date to datetime in table shape (5, 15)
# ✓ Converted Settle Date to datetime in table shape (72, 6)
# ✓ Converted Date to datetime in table shape (7, 7)
# ✓ Converted Date to datetime in table shape (153, 6)
# ✓ Converted Date to datetime in table shape (110, 6)
# ✓ Converted Date to datetime in table shape (56, 6)
# ✓ Converted Date to datetime in table shape (269, 15)
# ✓ Converted Ex Date to datetime in table shape (269, 15)
# ✓ Converted Pay Date to datetime in table shape (269, 15)
# ✓ Converted Value Date to datetime in table shape (256, 11)
# ✓ Converted Issue Date to datetime in table shape (5, 10)
# 💾 Saved all tables to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2021.pkl
# ✅ 31 tables saved for 2021.
#
# 📂 Processing U7212345_2022_2022.csv → saving to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2022
# 📦 Section processed: Statement_General → (5, 3)
# 📦 Section processed: Account Information_General → (6, 3)
# 📦 Section processed: Net Asset Value_General → (7, 7)
# 📦 Section processed: Net Asset Value_wRR → (1, 2)
# 📦 Section processed: Change in NAV_General → (13, 3)
# 📦 Section processed: Mark-to-Market Performance Summary_General → (90, 13)
# 📦 Section processed: Realized & Unrealized Performance Summary_General → (77, 16)
# 📦 Section processed: Cash Report_General → (91, 6)
# 📦 Section processed: Open Positions_Stocks → (19, 13)
# 📦 Section processed: Forex Balances_General → (7, 11)
# 📦 Section processed: Net Stock Position Summary_General → (15, 9)
# 📦 Section processed: Trades_Stocks → (186, 15)
# 📦 Section processed: Trades_Structured Products → (5, 15)
# 📦 Section processed: Trades_Forex → (73, 12)
# 📦 Section processed: Transaction Fees_General → (8, 10)
# 📦 Section processed: Corporate Actions_General → (22, 11)
# 📦 Section processed: Deposits & Withdrawals_General → (7, 5)
# 📦 Section processed: Fees_General → (3, 6)
# 📦 Section processed: Dividends_General → (105, 5)
# 📦 Section processed: Withholding Tax_General → (79, 6)
# 📦 Section processed: Interest_General → (38, 5)
# 📦 Section processed: Interest Accruals_General → (19, 4)
# 📦 Section processed: Change in Dividend Accruals_General → (210, 14)
# 📦 Section processed: Borrow Fee Details_General → (7, 10)
# 📦 Section processed: Financial Instrument Information_Stocks → (69, 11)
# 📦 Section processed: Financial Instrument Information_Structured Products → (1, 11)
# 📦 Section processed: Codes_General → (71, 5)
# 📦 Section processed: Notes/Legal Notes_General → (27, 3)
# ✓ Converted Date/Time to datetime in table shape (186, 15)
# ✓ Converted Date/Time to datetime in table shape (5, 15)
# ✓ Converted Date/Time to datetime in table shape (73, 10)
# ✓ Converted Date/Time to datetime in table shape (8, 9)
# ✓ Converted Report Date to datetime in table shape (22, 11)
# ✓ Converted Date/Time to datetime in table shape (22, 11)
# ✓ Converted Settle Date to datetime in table shape (7, 5)
# ✓ Converted Date to datetime in table shape (3, 6)
# ✓ Converted Date to datetime in table shape (105, 5)
# ✓ Converted Date to datetime in table shape (79, 5)
# ✓ Converted Date to datetime in table shape (38, 5)
# ✓ Converted Date to datetime in table shape (210, 14)
# ✓ Converted Ex Date to datetime in table shape (210, 14)
# ✓ Converted Pay Date to datetime in table shape (210, 14)
# ✓ Converted Value Date to datetime in table shape (7, 10)
# ✓ Converted Issue Date to datetime in table shape (1, 10)
# 💾 Saved all tables to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2022.pkl
# ✅ 28 tables saved for 2022.
#
# 📂 Processing U7212345_2023_2023.csv → saving to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2023
# 📦 Section processed: Statement_General → (5, 3)
# 📦 Section processed: Account Information_General → (6, 3)
# 📦 Section processed: Net Asset Value_General → (7, 7)
# 📦 Section processed: Net Asset Value_wRR → (1, 2)
# 📦 Section processed: Change in NAV_General → (12, 3)
# 📦 Section processed: Mark-to-Market Performance Summary_General → (46, 13)
# 📦 Section processed: Realized & Unrealized Performance Summary_General → (32, 16)
# 📦 Section processed: Cash Report_General → (56, 6)
# 📦 Section processed: Open Positions_Warrants → (3, 13)
# 📦 Section processed: Open Positions_Stocks → (13, 13)
# 📦 Section processed: Collateral for Customer Borrowing_General → (5, 15)
# 📦 Section processed: Forex Balances_General → (7, 11)
# 📦 Section processed: Net Stock Position Summary_General → (9, 9)
# 📦 Section processed: Trades_Warrants → (12, 15)
# 📦 Section processed: Trades_Stocks → (31, 15)
# 📦 Section processed: Trades_Forex → (16, 12)
# 📦 Section processed: Option Cash Settlements_General → (2, 5)
# 📦 Section processed: Corporate Actions_General → (9, 11)
# 📦 Section processed: Transfers_Stocks → (3, 15)
# 📦 Section processed: Deposits & Withdrawals_General → (5, 5)
# 📦 Section processed: Dividends_General → (40, 5)
# 📦 Section processed: Withholding Tax_General → (30, 6)
# 📦 Section processed: Interest_General → (19, 5)
# 📦 Section processed: Interest Accruals_General → (14, 4)
# 📦 Section processed: Change in Dividend Accruals_General → (80, 14)
# 📦 Section processed: Borrow Fee Details_General → (35, 10)
# 📦 Section processed: Financial Instrument Information_Warrants → (3, 12)
# 📦 Section processed: Financial Instrument Information_Stocks → (24, 11)
# 📦 Section processed: Codes_General → (71, 5)
# 📦 Section processed: Notes/Legal Notes_General → (27, 3)
# ✓ Converted Date/Time to datetime in table shape (12, 15)
# ✓ Converted Date/Time to datetime in table shape (31, 15)
# ✓ Converted Date/Time to datetime in table shape (16, 10)
# ✓ Converted Date to datetime in table shape (2, 5)
# ✓ Converted Report Date to datetime in table shape (9, 10)
# ✓ Converted Date/Time to datetime in table shape (9, 10)
# ✓ Converted Date to datetime in table shape (3, 14)
# ✓ Converted Settle Date to datetime in table shape (5, 5)
# ✓ Converted Date to datetime in table shape (40, 5)
# ✓ Converted Date to datetime in table shape (30, 5)
# ✓ Converted Date to datetime in table shape (19, 5)
# ✓ Converted Date to datetime in table shape (80, 14)
# ✓ Converted Ex Date to datetime in table shape (80, 14)
# ✓ Converted Pay Date to datetime in table shape (80, 14)
# ✓ Converted Value Date to datetime in table shape (35, 10)
# 💾 Saved all tables to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2023.pkl
# ✅ 30 tables saved for 2023.
#
# 📂 Processing U7212345_2024_2024.csv → saving to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2024
# 📦 Section processed: Statement_General → (5, 3)
# 📦 Section processed: Account Information_General → (6, 3)
# 📦 Section processed: Net Asset Value_General → (7, 7)
# 📦 Section processed: Net Asset Value_wRR → (1, 2)
# 📦 Section processed: Change in NAV_General → (13, 3)
# 📦 Section processed: Mark-to-Market Performance Summary_General → (46, 13)
# 📦 Section processed: Realized & Unrealized Performance Summary_General → (35, 16)
# 📦 Section processed: Cash Report_General → (53, 6)
# 📦 Section processed: Open Positions_Stocks → (10, 13)
# 📦 Section processed: Forex Balances_General → (3, 11)
# 📦 Section processed: Net Stock Position Summary_General → (6, 9)
# 📦 Section processed: Trades_Warrants → (8, 15)
# 📦 Section processed: Trades_Stocks → (55, 15)
# 📦 Section processed: Trades_CFDs → (5, 15)
# 📦 Section processed: Trades_Forex → (33, 12)
# 📦 Section processed: Corporate Actions_General → (7, 11)
# 📦 Section processed: Deposits & Withdrawals_General → (8, 5)
# 📦 Section processed: Fees_General → (33, 6)
# 📦 Section processed: Dividends_General → (24, 5)
# 📦 Section processed: Withholding Tax_General → (13, 6)
# 📦 Section processed: Interest_General → (10, 5)
# 📦 Section processed: Interest Accruals_General → (14, 4)
# 📦 Section processed: Change in Dividend Accruals_General → (37, 14)
# 📦 Section processed: Financial Instrument Information_Warrants → (3, 12)
# 📦 Section processed: Financial Instrument Information_Stocks → (22, 11)
# 📦 Section processed: Financial Instrument Information_CFDs → (1, 9)
# 📦 Section processed: Codes_General → (71, 5)
# 📦 Section processed: Notes/Legal Notes_General → (27, 3)
# ✓ Converted Date/Time to datetime in table shape (8, 15)
# ✓ Converted Date/Time to datetime in table shape (55, 15)
# ✓ Converted Date/Time to datetime in table shape (5, 15)
# ✓ Converted Date/Time to datetime in table shape (33, 10)
# ✓ Converted Report Date to datetime in table shape (7, 10)
# ✓ Converted Date/Time to datetime in table shape (7, 10)
# ✓ Converted Settle Date to datetime in table shape (8, 5)
# ✓ Converted Date to datetime in table shape (33, 6)
# ✓ Converted Date to datetime in table shape (24, 5)
# ✓ Converted Date to datetime in table shape (13, 5)
# ✓ Converted Date to datetime in table shape (10, 5)
# ✓ Converted Date to datetime in table shape (37, 14)
# ✓ Converted Ex Date to datetime in table shape (37, 14)
# ✓ Converted Pay Date to datetime in table shape (37, 14)
# 💾 Saved all tables to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2024.pkl
# ✅ 28 tables saved for 2024.
#
# 📂 Processing U7212345_2025_2025.csv → saving to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2025
# 📦 Section processed: Statement_General → (5, 3)
# 📦 Section processed: Account Information_General → (6, 3)
# 📦 Section processed: Net Asset Value_General → (6, 7)
# 📦 Section processed: Net Asset Value_wRR → (1, 2)
# 📦 Section processed: Change in NAV_General → (13, 3)
# 📦 Section processed: Mark-to-Market Performance Summary_General → (25, 13)
# 📦 Section processed: Realized & Unrealized Performance Summary_General → (12, 16)
# 📦 Section processed: Cash Report_General → (49, 6)
# 📦 Section processed: Open Positions_Stocks → (7, 13)
# 📦 Section processed: Forex Balances_General → (3, 11)
# 📦 Section processed: Net Stock Position Summary_General → (4, 9)
# 📦 Section processed: Trades_Warrants → (6, 15)
# 📦 Section processed: Trades_Stocks → (13, 15)
# 📦 Section processed: Trades_Forex → (6, 12)
# 📦 Section processed: Option Cash Settlements_General → (4, 5)
# 📦 Section processed: Deposits & Withdrawals_General → (4, 5)
# 📦 Section processed: Fees_General → (6, 6)
# 📦 Section processed: Dividends_General → (3, 5)
# 📦 Section processed: Withholding Tax_General → (3, 6)
# 📦 Section processed: Interest_General → (7, 5)
# 📦 Section processed: Interest Accruals_General → (14, 4)
# 📦 Section processed: Change in Dividend Accruals_General → (7, 14)
# 📦 Section processed: Stock Yield Enhancement Program Securities Lent_General → (6, 8)
# 📦 Section processed: Stock Yield Enhancement Program Securities Lent Activity_General → (28, 9)
# 📦 Section processed: Stock Yield Enhancement Program Securities Lent Interest Details_General → (10, 11)
# 📦 Section processed: Financial Instrument Information_Warrants → (1, 12)
# 📦 Section processed: Financial Instrument Information_Stocks → (6, 11)
# 📦 Section processed: Codes_General → (71, 5)
# 📦 Section processed: Notes/Legal Notes_General → (27, 3)
# ✓ Converted Date/Time to datetime in table shape (6, 15)
# ✓ Converted Date/Time to datetime in table shape (13, 15)
# ✓ Converted Date/Time to datetime in table shape (6, 10)
# ✓ Converted Date to datetime in table shape (4, 5)
# ✓ Converted Settle Date to datetime in table shape (4, 5)
# ✓ Converted Date to datetime in table shape (6, 6)
# ✓ Converted Date to datetime in table shape (3, 5)
# ✓ Converted Date to datetime in table shape (3, 5)
# ✓ Converted Date to datetime in table shape (7, 5)
# ✓ Converted Date to datetime in table shape (7, 14)
# ✓ Converted Ex Date to datetime in table shape (7, 14)
# ✓ Converted Pay Date to datetime in table shape (7, 14)
# ✓ Converted Date to datetime in table shape (28, 8)
# ✓ Converted Value Date to datetime in table shape (10, 11)
# ✓ Converted Start Date to datetime in table shape (10, 11)
# 💾 Saved all tables to: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2025.pkl
# ✅ 29 tables saved for 2025.
#
# 🧩 Merged all years into: D:\OneDrive\pyprojects\ibkit\data\processed\ibkr_2021_2025.pkl

# %%
# 🔓 Load merged .pkl (e.g. 2022 to 2025)
with open(".."/ processed_dir / "ibkr_2021_2025.pkl", "rb") as f:
    ibkr = pickle.load(f)

# 🗂️ Available years
print("Available years:", list(ibkr.keys()))
# Out:
# Available years: ['2021', '2022', '2023', '2024', '2025']

# %%
# 📑 Pick a subtable: year 2022, Trades.Stocks
df = ibkr["2021"]["Trades"]["Stocks"]

# 📈 Show first few rows
df.head()
# Out:
#      Header DataDiscriminator Asset Category Currency   Account Symbol  \
# 0      Data             Order         Stocks      CAD  U7212345    BCM
# 1  SubTotal              <NA>         Stocks      CAD      <NA>    BCM
# 2      Data             Order         Stocks      CAD  U7212345    SBB
# 3  SubTotal              <NA>         Stocks      CAD      <NA>    SBB
# 4     Total              <NA>         Stocks      CAD      <NA>   <NA>
#
#             Date/Time  Quantity  T. Price  C. Price  Proceeds  Comm/Fee  \
# 0 2021-01-27 09:54:50   -1000.0    2.4055      2.48    2405.5     -10.0
# 1                 NaT   -1000.0       NaN       NaN    2405.5     -10.0
# 2 2021-01-27 09:57:38   -1500.0    2.4300      2.41    3645.0     -15.0
# 3                 NaT   -1500.0       NaN       NaN    3645.0     -15.0
# 4                 NaT       NaN       NaN       NaN    6050.5     -25.0
#
#     Basis  Realized P/L  MTM P/L  Code
# 0 -3780.0       -1384.5    -74.5   C;P
# 1 -3780.0       -1384.5    -74.5  <NA>
# 2 -3285.0         345.0     30.0   C;P
# 3 -3285.0         345.0     30.0  <NA>
# 4 -7065.0       -1039.5    -44.5  <NA>

# %%
list(ibkr["2023"].keys())
# Out:
# ['Statement',
#  'Account Information',
#  'Net Asset Value',
#  'Change in NAV',
#  'Mark-to-Market Performance Summary',
#  'Realized & Unrealized Performance Summary',
#  'Cash Report',
#  'Open Positions',
#  'Collateral for Customer Borrowing',
#  'Forex Balances',
#  'Net Stock Position Summary',
#  'Trades',
#  'Option Cash Settlements',
#  'Corporate Actions',
#  'Transfers',
#  'Deposits & Withdrawals',
#  'Dividends',
#  'Withholding Tax',
#  'Interest',
#  'Interest Accruals',
#  'Change in Dividend Accruals',
#  'Borrow Fee Details',
#  'Financial Instrument Information',
#  'Codes',
#  'Notes/Legal Notes']

# %%
# 📑 Pick a subtable: year 2023, Open_Positions.Stocks
df = ibkr["2021"]["Open Positions"]["Stocks"]

# 📈 Show first few rows
df.head()
# Out:
#   Header DataDiscriminator Asset Category Currency Symbol  Quantity  Mult  \
# 0   Data           Summary         Stocks      EUR   BBZA      30.0   1.0
# 1   Data           Summary         Stocks      EUR   BNRd      30.0   1.0
# 2   Data           Summary         Stocks      EUR   COPd      40.0   1.0
# 3   Data           Summary         Stocks      EUR    CRC     100.0   1.0
# 4   Data           Summary         Stocks      EUR  EOANd     400.0   1.0
#
#    Cost Price  Cost Basis  Close Price   Value  Unrealized P/L Code
# 0   64.166667   1925.0000       74.400  2232.0        307.0000
# 1   69.069167   2072.0750       79.580  2387.4        315.3250
# 2   74.156250   2966.2500       71.150  2846.0       -120.2500
# 3   35.147565   3514.7565       37.010  3701.0        186.2435
# 4   10.177500   4071.0000       12.192  4876.8        805.8000

# %%
# 📑 Pick a subtable: year 2023, Open_Positions.Stocks
df = ibkr["2021"]["Open Positions"]["Stocks"]

# 📈 Show first few rows
df.head()
# Out:
#   Header DataDiscriminator Asset Category Currency Symbol  Quantity  Mult  \
# 0   Data           Summary         Stocks      EUR   BBZA      30.0   1.0
# 1   Data           Summary         Stocks      EUR   BNRd      30.0   1.0
# 2   Data           Summary         Stocks      EUR   COPd      40.0   1.0
# 3   Data           Summary         Stocks      EUR    CRC     100.0   1.0
# 4   Data           Summary         Stocks      EUR  EOANd     400.0   1.0
#
#    Cost Price  Cost Basis  Close Price   Value  Unrealized P/L Code
# 0   64.166667   1925.0000       74.400  2232.0        307.0000
# 1   69.069167   2072.0750       79.580  2387.4        315.3250
# 2   74.156250   2966.2500       71.150  2846.0       -120.2500
# 3   35.147565   3514.7565       37.010  3701.0        186.2435
# 4   10.177500   4071.0000       12.192  4876.8        805.8000

# %%
# 📑 Pick a subtable: year 2023, Open_Positions.Stocks
df = ibkr["2021"]["Financial Instrument Information"]["Stocks"]

# 📈 Show first few rows
df.head()
# Out:
#   Header Asset Category Symbol                 Description      Conid  \
# 0   Data         Stocks    390   CHINA RAILWAY GROUP LTD-H   47535520
# 1   Data         Stocks   AAPL                   APPLE INC     265598
# 2   Data         Stocks    ABI  ANHEUSER-BUSCH INBEV SA/NV  251259604
# 3   Data         Stocks     AG  FIRST MAJESTIC SILVER CORP   41855679
# 4   Data         Stocks    AMC              ALBEMARLE CORP   80702338
#
#     Security ID Underlying Listing Exch  Multiplier    Type Code
# 0  CNE1000007Z2                    SEHK           1  COMMON
# 1  US0378331005                  NASDAQ           1  COMMON
# 2  BE0974293251                ENEXT.BE           1  COMMON
# 3  CA32076V1031                    NYSE           1  COMMON
# 4  US0126531013                     FWB           1  COMMON
